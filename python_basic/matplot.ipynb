# %% [markdown]
# # Matplotlib Learning

# %% [markdown]
# # 1 Basic Use of Matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x=np.linspace(-1,1,50)
y=x*2+1

# create a window
plt.figure()
plt.plot(x,y)
plt.show()

# %%
x=np.linspace(-3,3,50)
y1=x*2+1
y2=x**2

plt.figure(num=3,figsize=(8,5))
plt.plot(x,y1)
plt.plot(x,y2,color='red',linewidth=1.0,linestyle='--')

# %%
plt.figure()
plt.plot(x,y1,label='linear line') # set label to be displayed in legent
plt.plot(x,y2,color='r',linewidth=1.0,linestyle='--',label='square line')

# set axis
plt.xlim((-1,2))
plt.ylim((-2,4))
plt.xlabel('X axis')
plt.ylabel('Y axis')

new_ticks=np.linspace(-1,2,5) # Sets the axis scale
print(new_ticks)
plt.xticks(new_ticks)
plt.yticks([-2, -1.8, -1, 1.22, 3],[r'$really\ bad$', r'$bad$', r'$normal$', r'$good$', r'$really\ good$'])


# set border
ax=plt.gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')


# adjust axis
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data',0))
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data',0))

# set legend
plt.legend(loc='lower right')

# set annotation
x0=1
y0=2*x0+1
plt.plot([x0,x0],[0,y0],'k--',linewidth=2.5)
plt.scatter([x0,],[y0,],s=50,color='b') # set dot

plt.annotate(r'$2x+1=%s$' % y0, xy=(x0, y0), xycoords='data', xytext=(+30, -30),
             textcoords='offset points', fontsize=16,
             arrowprops=dict(arrowstyle='->', connectionstyle="arc3,rad=.2"))


plt.show()
# Out:
# [-1.   -0.25  0.5   1.25  2.  ]

# %% [markdown]
# # 2 Draw Graph

# %%
n=1024
x=np.random.normal(0,1,n)
y=np.random.normal(0,1,n)
t=np.arctan2(y,x) # t is used for color

plt.scatter(x,y,c=t,s=50,alpha=.5)
plt.xticks(())
plt.yticks(())

plt.show()

# %%
n=12
x=np.arange(n)
y1=(1-x/float(n))*np.random.uniform(0.5,1.0,n)
y2=(1-x/float(n))*np.random.uniform(0.5,1.0,n)

plt.bar(x,y1,facecolor='#9999ff', edgecolor='white')
plt.bar(x,-y2,facecolor='#ff9999', edgecolor='black')
plt.xticks(())
plt.yticks(())

# add value for each bar
for a,b in zip(x,y1):
    plt.text(a,b+0.05,'%.2f' % b, ha='center',va='bottom')

for a,b in zip(x,y1):
    plt.text(a,-b-0.1,'%.2f' % b, ha='center',va='top')

plt.ylim((-1,1))
plt.show()

# %%
def f(x,y):
    # the height funcion
    return (1-x/2+x**5+y**3)*np.exp(-x**2-y**2)

n=256
x=np.linspace(-3,3,n)
y=np.linspace(-3,3,n)
X,Y=np.meshgrid(x,y) # connect each x value to y value to make a 2-D array

# put color in
plt.contourf(X,Y,f(X,Y), 8 ,alpha=.75,cmap=plt.cm.hot)
C=plt.contour(X,Y,f(X,Y),8,colors='black',linewidth=0.5)
plt.clabel(C,inline=True,fontsize=10) # add number
plt.xticks(())
plt.yticks(())
# Out:
# /tmp/ipykernel_1498/1252345194.py:12: UserWarning: The following kwargs were not used by contour: 'linewidth'
#   C=plt.contour(X,Y,f(X,Y),8,colors='black',linewidth=0.5)
# ([], [])

# %%
a = np.array([0.313660827978, 0.365348418405, 0.423733120134,
              0.365348418405, 0.439599930621, 0.525083754405,
              0.423733120134, 0.525083754405, 0.651536351379]).reshape(3,3)

plt.imshow(a,interpolation='nearest',cmap='hot',origin='lower') # origin是原点的位置
plt.colorbar(shrink=.92)

plt.xticks(())
plt.yticks(())
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D

fig=plt.figure()
ax=Axes3D(fig) # show axis in 3_D

X=np.arange(-4,4,0.25)
Y=np.arange(-4,4,0.25)
X,Y=np.meshgrid(X,Y)
R=np.sqrt(X**2+Y**2)
Z=np.sin(R)

ax.plot_surface(X,Y,Z,rstride=1,cstride=1,cmap=plt.get_cmap('rainbow'))

# projection
ax.contourf(X, Y, Z, zdir='z', offset=-2, cmap=plt.get_cmap('rainbow'))
# Out:
# /tmp/ipykernel_1498/1502657791.py:4: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax=Axes3D(fig) # show axis in 3_D

# %% [markdown]
# # 3 subplot

# %%
plt.subplot(2,2,1)
plt.plot([0,1],[0,1])

plt.subplot(2,2,2)
plt.plot([0,1],[0,2])

plt.subplot(2,2,3)
plt.plot([0,1],[0,1])

plt.subplot(2,2,4)
plt.plot([0,1],[0,2])
plt.show()

# %%
plt.subplot(2,1,1)
plt.plot([0,1],[0,1])

plt.subplot(2,3,4)
plt.plot([0,1],[0,2])
plt.subplot(235)
plt.plot([0,1],[0,3])
plt.subplot(236)
plt.plot([0,1],[0,4])

plt.show()  # 展示

# %%
plt.figure()
ax1 = plt.subplot2grid((3, 3), (0, 0), colspan=3)
ax1.plot([1, 2], [1, 2])    # 画小图
ax1.set_title('ax1_title')  # 设置小图的标题

ax2=plt.subplot2grid((3,3),(1,0),colspan=2)
ax2.plot([0,1],[0,1])
ax2.set_title('ax2_title')

ax3=plt.subplot2grid((3,3),(2,0),colspan=1)
ax3.plot([0,1],[0,1])
ax3.set_title('ax2_title')

ax4=plt.subplot2grid((3,3),(2,1),colspan=1)
ax4.plot([0,1],[0,1])
ax4.set_title('ax2_title')

ax5=plt.subplot2grid((3,3),(1,2),rowspan=2)
ax5.plot([0,1],[0,1])
ax5.set_title('ax2_title')

plt.show()

# %%
fig = plt.figure()

x = [1, 2, 3, 4, 5, 6, 7]
y = [1, 3, 4, 2, 5, 8, 6]

left, bottom, width, height = 0.1, 0.1, 0.8, 0.8

ax1 = fig.add_axes([left, bottom, width, height])
ax1.plot(x, y, 'r')
ax1.set_xlabel('x')
ax1.set_ylabel('y')
ax1.set_title('title')

left, bottom, width, height = 0.2, 0.6, 0.25, 0.25
ax2 = fig.add_axes([left, bottom, width, height])
ax2.plot(y, x, 'b')
ax2.set_xlabel('x')
ax2.set_ylabel('y')
ax2.set_title('title inside 1')

plt.show()

# %%
x = np.arange(0, 10, 0.1)

y1 = 0.05 * x**2

y2 = -1 * y1

fig, ax1 = plt.subplots()

# second y axis
ax2 = ax1.twinx()``

ax1.plot(x, y1, 'g-')   # green, solid line
ax1.set_xlabel('X data')
ax1.set_ylabel('Y1 data', color='g')

ax2.plot(x, y2, 'b-') # blue
ax2.set_ylabel('Y2 data', color='b')

plt.show()
